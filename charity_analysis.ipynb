# %%
#*******************************************************************************************
 #
 #  File Name:  charity_analysis.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, charity_analysis.ipynb, reads a csv file,
 #      charity_data.csv, in the folder, resources, and uses Python and neural 
 #      networks methods to determine the optimum neural network model parameters.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  12/02/2023      Initial Development                     Nicholas J. George
 #
 #******************************************************************************************/

import deep_learningx
import pandasx

import logx
logx.create_directory(logx.MODELS_DIRECTORY_PATH)

import charity_constants

import datetime
import io
import json
import pickle
import time

import pandas as pd

from IPython.display import clear_output

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from silence_tensorflow import silence_tensorflow
silence_tensorflow()

import tensorflow as tf
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="af0ed19f-aa61-4714-bb42-b81cab1e0c4f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0f0cb44d-f3e4-415d-b939-da76a0be0ebb":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"56741bbf98744956a99a0922198b79a8","client_comm_id":"f5651604737444f3bbc7be49f1ef219f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"0f0cb44d-f3e4-415d-b939-da76a0be0ebb","roots":{"p1002":"af0ed19f-aa61-4714-bb42-b81cab1e0c4f"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# 2024-05-07 08:40:06.941869: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
CONSTANT_LOCAL_FILE_NAME = 'charity_analysis.ipynb'


logx.set_log_mode(False)

logx.set_image_mode(False)


logx.begin_program('charity_analysis')

# %%
BINNING_DICTIONARY \
    = {'NAME': 1,
       'APPLICATION_TYPE': 156,
       'AFFILIATION': 33,
       'CLASSIFICATION': 6074,
       'USE_CASE': 146,
       'ORGANIZATION': 0,
       'INCOME_AMT': 728,
       'ASK_AMT': 53}

# %% [markdown]
# # <br> **Section 1: Extraction**

# %% [markdown]
# ## **1.1: Read the CSV data into a Pandas DataFrame**

# %%
data_type_dictionary \
    = {'EIN': str,
       'NAME':	str,
       'APPLICATION_TYPE': str,
       'AFFILIATION': str,
       'CLASSIFICATION': str,
       'USE_CASE': str,
       'ORGANIZATION': str,
       'STATUS': int,
       'INCOME_AMT': str,
       'SPECIAL_CONSIDERATIONS': str,
       'ASK_AMT': int,
       'IS_SUCCESSFUL': int}

charity_dataframe \
    = pd.read_csv(charity_constants.INPUT_FILE_PATH, dtype = data_type_dictionary)

logx.log_write_object(charity_dataframe)

# %% [markdown]
# ## **1.2: Display Charity DataFrame**

# %%
pandasx.return_formatted_table(charity_dataframe, 'Table 1.2: Charity Data Table')
# Out:
# <style type="text/css">
# #T_668c1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_668c1_row0_col0, #T_668c1_row0_col1, #T_668c1_row0_col2, #T_668c1_row0_col3, #T_668c1_row0_col4, #T_668c1_row0_col5, #T_668c1_row0_col6, #T_668c1_row0_col7, #T_668c1_row0_col8, #T_668c1_row0_col9, #T_668c1_row0_col10, #T_668c1_row0_col11, #T_668c1_row1_col0, #T_668c1_row1_col1, #T_668c1_row1_col2, #T_668c1_row1_col3, #T_668c1_row1_col4, #T_668c1_row1_col5, #T_668c1_row1_col6, #T_668c1_row1_col7, #T_668c1_row1_col8, #T_668c1_row1_col9, #T_668c1_row1_col10, #T_668c1_row1_col11, #T_668c1_row2_col0, #T_668c1_row2_col1, #T_668c1_row2_col2, #T_668c1_row2_col3, #T_668c1_row2_col4, #T_668c1_row2_col5, #T_668c1_row2_col6, #T_668c1_row2_col7, #T_668c1_row2_col8, #T_668c1_row2_col9, #T_668c1_row2_col10, #T_668c1_row2_col11, #T_668c1_row3_col0, #T_668c1_row3_col1, #T_668c1_row3_col2, #T_668c1_row3_col3, #T_668c1_row3_col4, #T_668c1_row3_col5, #T_668c1_row3_col6, #T_668c1_row3_col7, #T_668c1_row3_col8, #T_668c1_row3_col9, #T_668c1_row3_col10, #T_668c1_row3_col11, #T_668c1_row4_col0, #T_668c1_row4_col1, #T_668c1_row4_col2, #T_668c1_row4_col3, #T_668c1_row4_col4, #T_668c1_row4_col5, #T_668c1_row4_col6, #T_668c1_row4_col7, #T_668c1_row4_col8, #T_668c1_row4_col9, #T_668c1_row4_col10, #T_668c1_row4_col11, #T_668c1_row5_col0, #T_668c1_row5_col1, #T_668c1_row5_col2, #T_668c1_row5_col3, #T_668c1_row5_col4, #T_668c1_row5_col5, #T_668c1_row5_col6, #T_668c1_row5_col7, #T_668c1_row5_col8, #T_668c1_row5_col9, #T_668c1_row5_col10, #T_668c1_row5_col11, #T_668c1_row6_col0, #T_668c1_row6_col1, #T_668c1_row6_col2, #T_668c1_row6_col3, #T_668c1_row6_col4, #T_668c1_row6_col5, #T_668c1_row6_col6, #T_668c1_row6_col7, #T_668c1_row6_col8, #T_668c1_row6_col9, #T_668c1_row6_col10, #T_668c1_row6_col11, #T_668c1_row7_col0, #T_668c1_row7_col1, #T_668c1_row7_col2, #T_668c1_row7_col3, #T_668c1_row7_col4, #T_668c1_row7_col5, #T_668c1_row7_col6, #T_668c1_row7_col7, #T_668c1_row7_col8, #T_668c1_row7_col9, #T_668c1_row7_col10, #T_668c1_row7_col11, #T_668c1_row8_col0, #T_668c1_row8_col1, #T_668c1_row8_col2, #T_668c1_row8_col3, #T_668c1_row8_col4, #T_668c1_row8_col5, #T_668c1_row8_col6, #T_668c1_row8_col7, #T_668c1_row8_col8, #T_668c1_row8_col9, #T_668c1_row8_col10, #T_668c1_row8_col11, #T_668c1_row9_col0, #T_668c1_row9_col1, #T_668c1_row9_col2, #T_668c1_row9_col3, #T_668c1_row9_col4, #T_668c1_row9_col5, #T_668c1_row9_col6, #T_668c1_row9_col7, #T_668c1_row9_col8, #T_668c1_row9_col9, #T_668c1_row9_col10, #T_668c1_row9_col11 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_668c1">
#   <caption>Table 1.2: Charity Data Table</caption>
#   <thead>
#     <tr>
#       <th id="T_668c1_level0_col0" class="col_heading level0 col0" >EIN</th>
#       <th id="T_668c1_level0_col1" class="col_heading level0 col1" >NAME</th>
#       <th id="T_668c1_level0_col2" class="col_heading level0 col2" >APPLICATION_TYPE</th>
#       <th id="T_668c1_level0_col3" class="col_heading level0 col3" >AFFILIATION</th>
#       <th id="T_668c1_level0_col4" class="col_heading level0 col4" >CLASSIFICATION</th>
#       <th id="T_668c1_level0_col5" class="col_heading level0 col5" >USE_CASE</th>
#       <th id="T_668c1_level0_col6" class="col_heading level0 col6" >ORGANIZATION</th>
#       <th id="T_668c1_level0_col7" class="col_heading level0 col7" >STATUS</th>
#       <th id="T_668c1_level0_col8" class="col_heading level0 col8" >INCOME_AMT</th>
#       <th id="T_668c1_level0_col9" class="col_heading level0 col9" >SPECIAL_CONSIDERATIONS</th>
#       <th id="T_668c1_level0_col10" class="col_heading level0 col10" >ASK_AMT</th>
#       <th id="T_668c1_level0_col11" class="col_heading level0 col11" >IS_SUCCESSFUL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_668c1_row0_col0" class="data row0 col0" >10520599</td>
#       <td id="T_668c1_row0_col1" class="data row0 col1" >BLUE KNIGHTS MOTORCYCLE CLUB</td>
#       <td id="T_668c1_row0_col2" class="data row0 col2" >T10</td>
#       <td id="T_668c1_row0_col3" class="data row0 col3" >Independent</td>
#       <td id="T_668c1_row0_col4" class="data row0 col4" >C1000</td>
#       <td id="T_668c1_row0_col5" class="data row0 col5" >ProductDev</td>
#       <td id="T_668c1_row0_col6" class="data row0 col6" >Association</td>
#       <td id="T_668c1_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_668c1_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_668c1_row0_col9" class="data row0 col9" >N</td>
#       <td id="T_668c1_row0_col10" class="data row0 col10" >5,000</td>
#       <td id="T_668c1_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_668c1_row1_col0" class="data row1 col0" >10531628</td>
#       <td id="T_668c1_row1_col1" class="data row1 col1" >AMERICAN CHESAPEAKE CLUB CHARITABLE TR</td>
#       <td id="T_668c1_row1_col2" class="data row1 col2" >T3</td>
#       <td id="T_668c1_row1_col3" class="data row1 col3" >Independent</td>
#       <td id="T_668c1_row1_col4" class="data row1 col4" >C2000</td>
#       <td id="T_668c1_row1_col5" class="data row1 col5" >Preservation</td>
#       <td id="T_668c1_row1_col6" class="data row1 col6" >Co-operative</td>
#       <td id="T_668c1_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_668c1_row1_col8" class="data row1 col8" >1-9999</td>
#       <td id="T_668c1_row1_col9" class="data row1 col9" >N</td>
#       <td id="T_668c1_row1_col10" class="data row1 col10" >108,590</td>
#       <td id="T_668c1_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_668c1_row2_col0" class="data row2 col0" >10547893</td>
#       <td id="T_668c1_row2_col1" class="data row2 col1" >ST CLOUD PROFESSIONAL FIREFIGHTERS</td>
#       <td id="T_668c1_row2_col2" class="data row2 col2" >T5</td>
#       <td id="T_668c1_row2_col3" class="data row2 col3" >CompanySponsored</td>
#       <td id="T_668c1_row2_col4" class="data row2 col4" >C3000</td>
#       <td id="T_668c1_row2_col5" class="data row2 col5" >ProductDev</td>
#       <td id="T_668c1_row2_col6" class="data row2 col6" >Association</td>
#       <td id="T_668c1_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_668c1_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_668c1_row2_col9" class="data row2 col9" >N</td>
#       <td id="T_668c1_row2_col10" class="data row2 col10" >5,000</td>
#       <td id="T_668c1_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_668c1_row3_col0" class="data row3 col0" >10553066</td>
#       <td id="T_668c1_row3_col1" class="data row3 col1" >SOUTHSIDE ATHLETIC ASSOCIATION</td>
#       <td id="T_668c1_row3_col2" class="data row3 col2" >T3</td>
#       <td id="T_668c1_row3_col3" class="data row3 col3" >CompanySponsored</td>
#       <td id="T_668c1_row3_col4" class="data row3 col4" >C2000</td>
#       <td id="T_668c1_row3_col5" class="data row3 col5" >Preservation</td>
#       <td id="T_668c1_row3_col6" class="data row3 col6" >Trust</td>
#       <td id="T_668c1_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_668c1_row3_col8" class="data row3 col8" >10000-24999</td>
#       <td id="T_668c1_row3_col9" class="data row3 col9" >N</td>
#       <td id="T_668c1_row3_col10" class="data row3 col10" >6,692</td>
#       <td id="T_668c1_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_668c1_row4_col0" class="data row4 col0" >10556103</td>
#       <td id="T_668c1_row4_col1" class="data row4 col1" >GENETIC RESEARCH INSTITUTE OF THE DESERT</td>
#       <td id="T_668c1_row4_col2" class="data row4 col2" >T3</td>
#       <td id="T_668c1_row4_col3" class="data row4 col3" >Independent</td>
#       <td id="T_668c1_row4_col4" class="data row4 col4" >C1000</td>
#       <td id="T_668c1_row4_col5" class="data row4 col5" >Heathcare</td>
#       <td id="T_668c1_row4_col6" class="data row4 col6" >Trust</td>
#       <td id="T_668c1_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_668c1_row4_col8" class="data row4 col8" >100000-499999</td>
#       <td id="T_668c1_row4_col9" class="data row4 col9" >N</td>
#       <td i

# %% [markdown]
# # <br> **Section 2: Preprocessing**

# %% [markdown]
# ## **2.1: Change ASK_AMT Integers to Categories**

# %%
updated_charity_dataframe = charity_dataframe.copy()

updated_charity_dataframe = updated_charity_dataframe.rename(columns = {'ASK_AMT': 'TEMP'})


ask_amt_bins_integer_list \
    = [0, 10000, 25000, 100000, 500000, 1000000, 5000000, 10000000, 50000000, 100000000]

ask_amt_labels_string_list \
    = ['0-9999', '10000-24999', '25000-99999', '100000-499999', '500000-999999', '1M-5M', '5M-10M', '10M-50M', '50M+']


updated_charity_dataframe['ASK_AMT'] \
    = pd.cut \
        (x = updated_charity_dataframe['TEMP'],
         bins = ask_amt_bins_integer_list,
         labels = ask_amt_labels_string_list)

updated_charity_dataframe \
    = updated_charity_dataframe \
        [['EIN', 'NAME', 'APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
          'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT',
          'IS_SUCCESSFUL', 'TEMP']]


logx.log_write_object(updated_charity_dataframe['ASK_AMT'])

# %% [markdown]
# ## **2.2: Drop the Non-Beneficial ID Columns**

# %%
drop_columns_string_list = ['EIN', 'STATUS', 'SPECIAL_CONSIDERATIONS', 'TEMP']

if updated_charity_dataframe.columns.isin(drop_columns_string_list).any():

    updated_charity_dataframe.drop(drop_columns_string_list, axis = 1, inplace = True)
    

logx.log_write_object(updated_charity_dataframe)

# %% [markdown]
# ## **2.3: Bin Columns**

# %% [markdown]
# ### **NAME**

# %%
updated_charity_dataframe['NAME'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['NAME'], BINNING_DICTIONARY['NAME'], 'OTHER')

logx.log_write_object \
    (updated_charity_dataframe['NAME'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **APPLICATION_TYPE**

# %%
updated_charity_dataframe['APPLICATION_TYPE'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['APPLICATION_TYPE'], BINNING_DICTIONARY['APPLICATION_TYPE'], 'T20')

logx.log_write_object \
    (updated_charity_dataframe['APPLICATION_TYPE'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **AFFILIATION**

# %%
updated_charity_dataframe['AFFILIATION'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['AFFILIATION'], BINNING_DICTIONARY['AFFILIATION'], 'OTHER')

logx.log_write_object \
    (updated_charity_dataframe['AFFILIATION'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **CLASSIFICATION**

# %%
updated_charity_dataframe['CLASSIFICATION'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['CLASSIFICATION'], BINNING_DICTIONARY['CLASSIFICATION'], 'C2200')

updated_charity_dataframe['CLASSIFICATION'] \
    = updated_charity_dataframe['CLASSIFICATION'].replace('C0', 'C0000')

logx.log_write_object \
    (updated_charity_dataframe['CLASSIFICATION'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **USE_CASE**

# %%
updated_charity_dataframe['USE_CASE'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['USE_CASE'], BINNING_DICTIONARY['USE_CASE'], 'OTHER')

logx.log_write_object \
    (updated_charity_dataframe['USE_CASE'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **ORGANIZATION**

# %%
updated_charity_dataframe['ORGANIZATION'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['ORGANIZATION'], BINNING_DICTIONARY['ORGANIZATION'], 'CORPORATION')

logx.log_write_object \
    (updated_charity_dataframe['AFFILIATION'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **INCOME_AMT**

# %%
updated_charity_dataframe['INCOME_AMT'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['INCOME_AMT'], BINNING_DICTIONARY['INCOME_AMT'], 'OTHER')

logx.log_write_object \
    (updated_charity_dataframe['INCOME_AMT'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ### **ASK_AMT**

# %%
updated_charity_dataframe['ASK_AMT'] \
    = deep_learningx.bin_series \
        (updated_charity_dataframe['ASK_AMT'], BINNING_DICTIONARY['ASK_AMT'], 'OTHER')

logx.log_write_object \
    (updated_charity_dataframe['ASK_AMT'].value_counts().sort_values(ascending = False))

# %% [markdown]
# ## **2.4: Convert All Features to Uppercase**

# %%
updated_charity_dataframe['NAME'] = updated_charity_dataframe['NAME'].str.upper()

updated_charity_dataframe['APPLICATION_TYPE'] = updated_charity_dataframe['APPLICATION_TYPE'].str.upper()

updated_charity_dataframe['AFFILIATION'] = updated_charity_dataframe['AFFILIATION'].str.upper()

updated_charity_dataframe['CLASSIFICATION'] = updated_charity_dataframe['CLASSIFICATION'].str.upper()

updated_charity_dataframe['USE_CASE'] = updated_charity_dataframe['USE_CASE'].str.upper()

updated_charity_dataframe['ORGANIZATION'] = updated_charity_dataframe['ORGANIZATION'].str.upper()

updated_charity_dataframe['INCOME_AMT'] = updated_charity_dataframe['INCOME_AMT'].str.upper()

updated_charity_dataframe['ASK_AMT'] = updated_charity_dataframe['ASK_AMT'].str.upper()

logx.log_write_object(updated_charity_dataframe)

# %% [markdown]
# ## **2.5: Display Updated DataFrame**

# %%
pandasx.return_formatted_table(updated_charity_dataframe, 'Table 2.5: Updated Charity Data Table')
# Out:
# <style type="text/css">
# #T_d2a0a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d2a0a_row0_col0, #T_d2a0a_row0_col1, #T_d2a0a_row0_col2, #T_d2a0a_row0_col3, #T_d2a0a_row0_col4, #T_d2a0a_row0_col5, #T_d2a0a_row0_col6, #T_d2a0a_row0_col7, #T_d2a0a_row0_col8, #T_d2a0a_row1_col0, #T_d2a0a_row1_col1, #T_d2a0a_row1_col2, #T_d2a0a_row1_col3, #T_d2a0a_row1_col4, #T_d2a0a_row1_col5, #T_d2a0a_row1_col6, #T_d2a0a_row1_col7, #T_d2a0a_row1_col8, #T_d2a0a_row2_col0, #T_d2a0a_row2_col1, #T_d2a0a_row2_col2, #T_d2a0a_row2_col3, #T_d2a0a_row2_col4, #T_d2a0a_row2_col5, #T_d2a0a_row2_col6, #T_d2a0a_row2_col7, #T_d2a0a_row2_col8, #T_d2a0a_row3_col0, #T_d2a0a_row3_col1, #T_d2a0a_row3_col2, #T_d2a0a_row3_col3, #T_d2a0a_row3_col4, #T_d2a0a_row3_col5, #T_d2a0a_row3_col6, #T_d2a0a_row3_col7, #T_d2a0a_row3_col8, #T_d2a0a_row4_col0, #T_d2a0a_row4_col1, #T_d2a0a_row4_col2, #T_d2a0a_row4_col3, #T_d2a0a_row4_col4, #T_d2a0a_row4_col5, #T_d2a0a_row4_col6, #T_d2a0a_row4_col7, #T_d2a0a_row4_col8, #T_d2a0a_row5_col0, #T_d2a0a_row5_col1, #T_d2a0a_row5_col2, #T_d2a0a_row5_col3, #T_d2a0a_row5_col4, #T_d2a0a_row5_col5, #T_d2a0a_row5_col6, #T_d2a0a_row5_col7, #T_d2a0a_row5_col8, #T_d2a0a_row6_col0, #T_d2a0a_row6_col1, #T_d2a0a_row6_col2, #T_d2a0a_row6_col3, #T_d2a0a_row6_col4, #T_d2a0a_row6_col5, #T_d2a0a_row6_col6, #T_d2a0a_row6_col7, #T_d2a0a_row6_col8, #T_d2a0a_row7_col0, #T_d2a0a_row7_col1, #T_d2a0a_row7_col2, #T_d2a0a_row7_col3, #T_d2a0a_row7_col4, #T_d2a0a_row7_col5, #T_d2a0a_row7_col6, #T_d2a0a_row7_col7, #T_d2a0a_row7_col8, #T_d2a0a_row8_col0, #T_d2a0a_row8_col1, #T_d2a0a_row8_col2, #T_d2a0a_row8_col3, #T_d2a0a_row8_col4, #T_d2a0a_row8_col5, #T_d2a0a_row8_col6, #T_d2a0a_row8_col7, #T_d2a0a_row8_col8, #T_d2a0a_row9_col0, #T_d2a0a_row9_col1, #T_d2a0a_row9_col2, #T_d2a0a_row9_col3, #T_d2a0a_row9_col4, #T_d2a0a_row9_col5, #T_d2a0a_row9_col6, #T_d2a0a_row9_col7, #T_d2a0a_row9_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d2a0a">
#   <caption>Table 2.5: Updated Charity Data Table</caption>
#   <thead>
#     <tr>
#       <th id="T_d2a0a_level0_col0" class="col_heading level0 col0" >NAME</th>
#       <th id="T_d2a0a_level0_col1" class="col_heading level0 col1" >APPLICATION_TYPE</th>
#       <th id="T_d2a0a_level0_col2" class="col_heading level0 col2" >AFFILIATION</th>
#       <th id="T_d2a0a_level0_col3" class="col_heading level0 col3" >CLASSIFICATION</th>
#       <th id="T_d2a0a_level0_col4" class="col_heading level0 col4" >USE_CASE</th>
#       <th id="T_d2a0a_level0_col5" class="col_heading level0 col5" >ORGANIZATION</th>
#       <th id="T_d2a0a_level0_col6" class="col_heading level0 col6" >INCOME_AMT</th>
#       <th id="T_d2a0a_level0_col7" class="col_heading level0 col7" >ASK_AMT</th>
#       <th id="T_d2a0a_level0_col8" class="col_heading level0 col8" >IS_SUCCESSFUL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2a0a_row0_col0" class="data row0 col0" >BLUE KNIGHTS MOTORCYCLE CLUB</td>
#       <td id="T_d2a0a_row0_col1" class="data row0 col1" >T10</td>
#       <td id="T_d2a0a_row0_col2" class="data row0 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row0_col3" class="data row0 col3" >C1000</td>
#       <td id="T_d2a0a_row0_col4" class="data row0 col4" >PRODUCTDEV</td>
#       <td id="T_d2a0a_row0_col5" class="data row0 col5" >ASSOCIATION</td>
#       <td id="T_d2a0a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_d2a0a_row0_col7" class="data row0 col7" >0-9999</td>
#       <td id="T_d2a0a_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row1_col0" class="data row1 col0" >OTHER</td>
#       <td id="T_d2a0a_row1_col1" class="data row1 col1" >T3</td>
#       <td id="T_d2a0a_row1_col2" class="data row1 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row1_col3" class="data row1 col3" >C2200</td>
#       <td id="T_d2a0a_row1_col4" class="data row1 col4" >PRESERVATION</td>
#       <td id="T_d2a0a_row1_col5" class="data row1 col5" >CO-OPERATIVE</td>
#       <td id="T_d2a0a_row1_col6" class="data row1 col6" >OTHER</td>
#       <td id="T_d2a0a_row1_col7" class="data row1 col7" >100000-499999</td>
#       <td id="T_d2a0a_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row2_col0" class="data row2 col0" >OTHER</td>
#       <td id="T_d2a0a_row2_col1" class="data row2 col1" >T5</td>
#       <td id="T_d2a0a_row2_col2" class="data row2 col2" >COMPANYSPONSORED</td>
#       <td id="T_d2a0a_row2_col3" class="data row2 col3" >C2200</td>
#       <td id="T_d2a0a_row2_col4" class="data row2 col4" >PRODUCTDEV</td>
#       <td id="T_d2a0a_row2_col5" class="data row2 col5" >ASSOCIATION</td>
#       <td id="T_d2a0a_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_d2a0a_row2_col7" class="data row2 col7" >0-9999</td>
#       <td id="T_d2a0a_row2_col8" class="data row2 col8" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row3_col0" class="data row3 col0" >OTHER</td>
#       <td id="T_d2a0a_row3_col1" class="data row3 col1" >T3</td>
#       <td id="T_d2a0a_row3_col2" class="data row3 col2" >COMPANYSPONSORED</td>
#       <td id="T_d2a0a_row3_col3" class="data row3 col3" >C2200</td>
#       <td id="T_d2a0a_row3_col4" class="data row3 col4" >PRESERVATION</td>
#       <td id="T_d2a0a_row3_col5" class="data row3 col5" >TRUST</td>
#       <td id="T_d2a0a_row3_col6" class="data row3 col6" >OTHER</td>
#       <td id="T_d2a0a_row3_col7" class="data row3 col7" >0-9999</td>
#       <td id="T_d2a0a_row3_col8" class="data row3 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row4_col0" class="data row4 col0" >OTHER</td>
#       <td id="T_d2a0a_row4_col1" class="data row4 col1" >T3</td>
#       <td id="T_d2a0a_row4_col2" class="data row4 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row4_col3" class="data row4 col3" >C1000</td>
#       <td id="T_d2a0a_row4_col4" class="data row4 col4" >OTHER</td>
#       <td id="T_d2a0a_row4_col5" class="data row4 col5" >TRUST</td>
#       <td id="T_d2a0a_row4_col6" class="data row4 col6" >100000-499999</td>
#       <td id="T_d2a0a_row4_col7" class="data row4 col7" >100000-499999</td>
#       <td id="T_d2a0a_row4_col8" class="data row4 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row5_col0" class="data row5 col0" >OTHER</td>
#       <td id="T_d2a0a_row5_col1" class="data row5 col1" >T3</td>
#       <td id="T_d2a0a_row5_col2" class="data row5 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row5_col3" class="data row5 col3" >C2200</td>
#       <td id="T_d2a0a_row5_col4" class="data row5 col4" >PRESERVATION</td>
#       <td id="T_d2a0a_row5_col5" class="data row5 col5" >TRUST</td>
#       <td id="T_d2a0a_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_d2a0a_row5_col7" class="data row5 col7" >0-9999</td>
#       <td id="T_d2a0a_row5_col8" class="data row5 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row6_col0" class="data row6 col0" >OTHER</td>
#       <td id="T_d2a0a_row6_col1" class="data row6 col1" >T3</td>
#       <td id="T_d2a0a_row6_col2" class="data row6 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row6_col3" class="data row6 col3" >C1000</td>
#       <td id="T_d2a0a_row6_col4" class="data row6 col4" >PRESERVATION</td>
#       <td id="T_d2a0a_row6_col5" class="data row6 col5" >TRUST</td>
#       <td id="T_d2a0a_row6_col6" class="data row6 col6" >100000-499999</td>
#       <td id="T_d2a0a_row6_col7" class="data row6 col7" >25000-99999</td>
#       <td id="T_d2a0a_row6_col8" class="data row6 col8" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d2a0a_row7_col0" class="data row7 col0" >OTHER</td>
#       <td id="T_d2a0a_row7_col1" class="data row7 col1" >T3</td>
#       <td id="T_d2a0a_row7_col2" class="data row7 col2" >INDEPENDENT</td>
#       <td id="T_d2a0a_row7_col3" class="data row7 col3" >C2200</td>
#       <td id="T_d2a0a_row7_col4" class="data row7 col4" >PRESERVATION</td>
#       <td id="T_d2a0a_row7_col5" class="data row7 col5" >TRUST</td>
#       <td id="T_d2a0a_row7_col6" class="data row7 col6" >OTHER</td>
#       <td id="T_d2a0a_row7_col7" class="data row7 col7" >5M-10M</td>
#       <td id="T_

# %% [markdown]
# # <br> **Section 3: Compile, Train, Evaluate, and Export the Model**

# %% [markdown]
# ## **3.1: Convert and Split Data Set**

# %% [markdown]
# ### **Convert Categorical Data to Numeric with `pd.get_dummies`**

# %%
dummies_dataframe = pd.get_dummies(updated_charity_dataframe)

logx.log_write_object(dummies_dataframe)

# %% [markdown]
# ### **Split Data Set into Features and Target Arrays**

# %%
y_nparray = dummies_dataframe['IS_SUCCESSFUL'].values

logx.log_write_object(y_nparray)

# %%
x_nparray = dummies_dataframe.drop(['IS_SUCCESSFUL'], axis = 1).values

logx.log_write_object(x_nparray)

# %% [markdown]
# ### **Split X-Y Arrays into Training and Testing Arrays**

# %%
x_train_nparray, x_test_nparray, y_train_nparray, y_test_nparray \
    = train_test_split \
        (x_nparray, y_nparray, 
         test_size = charity_constants.NN_TEST_SIZE,
         random_state = charity_constants.NN_RANDOM_STATE)

logx.log_write_object(str(x_train_nparray) + '\n\n')

logx.log_write_object(str(x_test_nparray) + '\n\n')

logx.log_write_object(str(y_train_nparray) + '\n\n')

logx.log_write_object(str(y_test_nparray) + '\n\n')

# %% [markdown]
# ## **3.2: Create and Compile Model**

# %% [markdown]
# ### **Set Hyperparameters**

# %%
number_input_features_integer = len(x_train_nparray[0])

logx.print_and_log_text \
    ('\033[1m'
     + 'The number of inputs (features) in the model is {:,}.' \
         .format(number_input_features_integer)
     + '\033[0m')
# Out:
# The number of inputs (features) in the model is 830.

# %%
first_layer_units_integer = 57

first_layer_activation_string = 'selu'

logx.print_and_log_text \
    ('\033[1m'
     + 'The number of nodes in the first layer is {:,}.' \
         .format(first_layer_units_integer)
     + '\033[0m')
# Out:
# The number of nodes in the first layer is 57.

# %%
second_layer_units_integer = 20

second_layer_activation_string = 'selu'

logx.print_and_log_text \
    ('\033[1m'
     + 'The number of nodes in the second layer is {:,}.' \
         .format(second_layer_units_integer)
     + '\033[0m')
# Out:
# The number of nodes in the second layer is 20.

# %%
output_layer_units_integer = 1

output_layer_activation_string = 'linear'

logx.print_and_log_text \
    ('\033[1m'
     + 'The number of nodes in the output layer is {:,}.' \
         .format(output_layer_units_integer)
     + '\033[0m')
# Out:
# The number of nodes in the output layer is 1.

# %% [markdown]
# ### **Instantiate the Model**

# %%
sequential_neural_network_model = tf.keras.models.Sequential()

# %%
sequential_neural_network_model.add \
    (tf.keras.layers.Dense \
         (units = first_layer_units_integer,
          activation = first_layer_activation_string,
          input_dim = number_input_features_integer))

sequential_neural_network_model.add(tf.keras.layers.Dropout(0.012928))

sequential_neural_network_model.add \
    (tf.keras.layers.Dense \
         (units = second_layer_units_integer,
          activation = second_layer_activation_string))

sequential_neural_network_model.add(tf.keras.layers.Dropout(0.011161))

sequential_neural_network_model.add \
    (tf.keras.layers.Dense \
         (units = output_layer_units_integer,
          activation = output_layer_activation_string))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### **Model Summary**

# %%
sequential_neural_network_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 57)             │        47,367 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 57)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,548 (189.64 KB)
#  Trainable params: 48,548 (189.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### **Compile**

# %%
sequential_neural_network_model.compile \
    (loss = 'huber',
     optimizer = tf.keras.optimizers.Adamax(learning_rate = 0.0025815),
     metrics = ['accuracy'])

# %% [markdown]
# ## **3.3: Fit and Train Model**

# %%
earlystopping_callback \
    = tf.keras.callbacks.EarlyStopping  \
        (monitor = 'val_accuracy', 
         mode = 'max', 
         patience = 100, 
         restore_best_weights = True)

sequential_neural_network_model \
    .fit \
        (x_train_nparray, y_train_nparray, 
         batch_size = charity_constants.NN_BATCH_SIZE,
         validation_split = charity_constants.NN_TEST_SIZE,
         epochs = charity_constants.NN_MAX_EPOCHS, 
         verbose = charity_constants.NN_VERBOSE,
         validation_data = (x_test_nparray, y_test_nparray),
         callbacks = [earlystopping_callback])
# Out:
# Epoch 1/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7372 - loss: 0.0928 - val_accuracy: 0.7915 - val_loss: 0.0733
# Epoch 2/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.7906 - loss: 0.0749 - val_accuracy: 0.7959 - val_loss: 0.0727
# Epoch 3/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.7922 - loss: 0.0739 - val_accuracy: 0.8001 - val_loss: 0.0704
# Epoch 4/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7997 - loss: 0.0712 - val_accuracy: 0.7990 - val_loss: 0.0701
# Epoch 5/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.8007 - loss: 0.0710 - val_accuracy: 0.7999 - val_loss: 0.0747
# Epoch 6/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.7985 - loss: 0.0716 - val_accuracy: 0.7997 - val_loss: 0.0718
# Epoch 7/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.7986 - loss: 0.0710 - val_accuracy: 0.8010 - val_loss: 0.0696
# Epoch 8/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.7988 - loss: 0.0702 - val_accuracy: 0.7994 - val_loss: 0.0710
# Epoch 9/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.8003 - loss: 0.0701 - val_accuracy: 0.8079 - val_loss: 0.0690
# Epoch 10/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7981 - loss: 0.0703 - val_accuracy: 0.8080 - val_loss: 0.0688
# Epoch 11/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.8061 - loss: 0.0687 - val_accuracy: 0.8036 - val_loss: 0.0697
# Epoch 12/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.8037 - loss: 0.0696 - val_accuracy: 0.8035 - val_loss: 0.0693
# Epoch 13/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.8061 - loss: 0.0687 - val_accuracy: 0.8083 - val_loss: 0.0687
# Epoch 14/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.8039 - loss: 0.0685 - val_accuracy: 0.8061 - val_loss: 0.0688
# Epoch 15/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7978 - loss: 0.0702 - val_accuracy: 0.8064 - val_loss: 0.0689
# Epoch 16/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.8075 - loss: 0.0683 - val_accuracy: 0.8038 - val_loss: 0.0689
# Epoch 17/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.8084 - loss: 0.0675 - val_accuracy: 0.8092 - val_loss: 0.0689
# Epoch 18/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.8026 - loss: 0.0690 - val_accuracy: 0.8074 - val_loss: 0.0686
# Epoch 19/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.8019 - loss: 0.0689 - val_accuracy: 0.8089 - val_loss: 0.0685
# Epoch 20/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.8075 - loss: 0.0677 - val_accuracy: 0.8054 - val_loss: 0.0695
# Epoch 21/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8096 - loss: 0.0667 - val_accuracy: 0.8102 - val_loss: 0.0683
# Epoch 277/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8062 - loss: 0.0674 - val_accuracy: 0.8108 - val_loss: 0.0684
# Epoch 278/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8026 - loss: 0.0683 - val_accuracy: 0.8121 - val_loss: 0.0678
# Epoch 279/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8143 - loss: 0.0652 - val_accuracy: 0.8045 - val_loss: 0.0691
# Epoch 280/1000
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8108 - loss: 0.0663 - val_accuracy: 0.8109 - val_loss: 0.0679

# %% [markdown]
# ## **3.4: Evaluate the Model**

# %%
model_loss_float, model_accuracy_float \
    = sequential_neural_network_model.evaluate(x_test_nparray, y_test_nparray, verbose = 2)

logx.print_and_log_text \
    (f'\nModel Loss: {round(model_loss_float * 100, 2)}%, '
     + f'Model Accuracy: {round(model_accuracy_float * 100, 2)}%')
# Out:
# 215/215 - 0s - 513us/step - accuracy: 0.8141 - loss: 0.0678
#
# Model Loss: 6.78%, Model Accuracy: 81.41%

# %% [markdown]
# ## **3.5: Save and Export Model**

# %%
sequential_neural_network_model.save(charity_constants.MODEL_FILE_PATH)

# %% [markdown]
# # <br> **Section 4: Predict Charity Funding Success**

# %% [markdown]
# ## **4.1: Reload Model**

# %%
reloaded_sequential_neural_network_model \
    = tf.keras.models.load_model \
        (charity_constants.MODEL_FILE_PATH)

# %% [markdown]
# ## **4.2: Predictions**

# %%
predictions_nparray \
    = reloaded_sequential_neural_network_model.predict \
        (x_test_nparray).round().astype('int32')

predictions_dataframe = pd.DataFrame(predictions_nparray).idxmax(axis = 1)

predictions_nparray = predictions_dataframe.values
# Out:
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step

# %%
y_test_dataframe = pd.DataFrame(y_test_nparray).idxmax(axis = 1)

y_test_nparray = y_test_dataframe.values

# %% [markdown]
# ## **4.3: Compare Predictions and Actual Values**

# %%
comparison_dataframe \
    = pd.DataFrame \
        ({'predictions': predictions_nparray.ravel(), 
          'actual': y_test_nparray})

# %%
pandasx.return_formatted_table \
    (comparison_dataframe, 
     'Table 4.3: Model Predictions vs. Actual Values')
# Out:
# <style type="text/css">
# #T_aacee caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_aacee_row0_col0, #T_aacee_row0_col1, #T_aacee_row1_col0, #T_aacee_row1_col1, #T_aacee_row2_col0, #T_aacee_row2_col1, #T_aacee_row3_col0, #T_aacee_row3_col1, #T_aacee_row4_col0, #T_aacee_row4_col1, #T_aacee_row5_col0, #T_aacee_row5_col1, #T_aacee_row6_col0, #T_aacee_row6_col1, #T_aacee_row7_col0, #T_aacee_row7_col1, #T_aacee_row8_col0, #T_aacee_row8_col1, #T_aacee_row9_col0, #T_aacee_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_aacee">
#   <caption>Table 4.3: Model Predictions vs. Actual Values</caption>
#   <thead>
#     <tr>
#       <th id="T_aacee_level0_col0" class="col_heading level0 col0" >predictions</th>
#       <th id="T_aacee_level0_col1" class="col_heading level0 col1" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aacee_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_aacee_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_aacee_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_aacee_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_aacee_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_aacee_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_aacee_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_aacee_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_aacee_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_aacee_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aacee_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_aacee_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# logx.end_program()
